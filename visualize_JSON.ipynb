# %%
# %matplotlib inline
from pycocotools.coco import COCO
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab

# %%
image_directory = '../NUbotsDataSet/train/resize/imgs/'
annotation_file = '../NUbotsDataSet/train/resize/NUbots_Dataset_A.json'

# %%
example_coco = COCO(annotation_file)
# Out:
# loading annotations into memory...
# Done (t=2.11s)
# creating index...
# index created!

# %%
categories = example_coco.loadCats(example_coco.getCatIds())
category_names = [category['name'] for category in categories]
print('Custom categories: \n{}\n'.format(' '.join(category_names)))

category_names = set([category['supercategory'] for category in categories])
print('Custom supercategories: \n{}'.format(' '.join(category_names)))
# Out:
# Custom categories:
# goal field marking ball BG
#
# Custom supercategories:
# item background

# %%
category_ids = example_coco.getCatIds(catNms=['marking'])
print(category_ids)
image_ids = example_coco.getImgIds(catIds=category_ids)
print(image_ids)
image_data = example_coco.loadImgs(image_ids[np.random.randint(0, len(image_ids))])[0]
# Out:
# [3]
# ...

# %%
image_data
# Out:
# {'id': 9570,
#  'file_name': '0000004785_R.jpg',
#  'width': 640,
#  'height': 512,
#  'date_captured': '2020-04-15 11:34:25.291651',
#  'license': 1,
#  'coco_url': '',
#  'flickr_url': ''}

# %%
# load and display instance annotations
image = io.imread(image_directory + image_data['file_name'])
plt.imshow(image); plt.axis('off')
pylab.rcParams['figure.figsize'] = (8.0, 10.0)
annotation_ids = example_coco.getAnnIds(imgIds=image_data['id'], catIds=category_ids, iscrowd=None)
annotations = example_coco.loadAnns(annotation_ids)
example_coco.showAnns(annotations)
